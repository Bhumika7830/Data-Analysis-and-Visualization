# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Shivani\Downloads\heart_data_set.csv")

# %%
df
# Out:
#      age  Gender  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0     63       1              3                   145          233
# 1     37       1              2                   130          250
# 2     41       0              1                   130          204
# 3     56       1              1                   120          236
# 4     57       0              0                   120          354
# ..   ...     ...            ...                   ...          ...
# 298   57       0              0                   140          241
# 299   45       1              3                   110          264
# 300   68       1              0                   144          193
# 301   57       1              0                   130          131
# 302   57       0              1                   130          236
#
#      FastingBloodSugar  RestingECG  MaxHeartRate  ExerciseInducedAngina  \
# 0                    1           0           150                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    303 non-null    int64
#  1   Gender                 303 non-null    int64
#  2   ChestPainType          303 non-null    int64
#  3   RestingBloodPressure   303 non-null    int64
#  4   Cholesterol            303 non-null    int64
#  5   FastingBloodSugar      303 non-null    int64
#  6   RestingECG             303 non-null    int64
#  7   MaxHeartRate           303 non-null    int64
#  8   ExerciseInducedAngina  303 non-null    int64
#  9   STDepression           303 non-null    float64
#  10  Slope                  303 non-null    int64
#  11  NumMajorVessels        303 non-null    int64
#  12  Thalassemia            303 non-null    int64
#  13  HeartDiseasePresence   303 non-null    int64
# dtypes: float64(1), int64(13)
# ...

# %%
df.head()#gives top 10 values
# Out:
#    age  Gender  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0   63       1              3                   145          233
# 1   37       1              2                   130          250
# 2   41       0              1                   130          204
# 3   56       1              1                   120          236
# 4   57       0              0                   120          354
#
#    FastingBloodSugar  RestingECG  MaxHeartRate  ExerciseInducedAngina  \
# 0                  1           0           150                      0
# 1                  0           1           187                      0
# 2                  0           0           172                      0
# 3                  0           1           178                      0
# 4                  0           1           163                      1
#
#    STDepression  Slope  NumMajorVessels  Thalassemia  HeartDiseasePresence
# 0           2.3      0                0            1                     1
# ...

# %%
df.tail()#gives last 10 values
# Out:
#      age  Gender  ChestPainType  RestingBloodPressure  Cholesterol  \
# 298   57       0              0                   140          241
# 299   45       1              3                   110          264
# 300   68       1              0                   144          193
# 301   57       1              0                   130          131
# 302   57       0              1                   130          236
#
#      FastingBloodSugar  RestingECG  MaxHeartRate  ExerciseInducedAngina  \
# 298                  0           1           123                      1
# 299                  0           1           132                      0
# 300                  1           1           141                      0
# 301                  0           1           115                      1
# 302                  0           0           174                      0
#
#      STDepression  Slope  NumMajorVessels  Thalassemia  HeartDiseasePresence
# ...

# %%
df.sample()#returns a random row
# Out:
#      age  Gender  ChestPainType  RestingBloodPressure  Cholesterol  \
# 136   60       0              2                   120          178
#
#      FastingBloodSugar  RestingECG  MaxHeartRate  ExerciseInducedAngina  \
# 136                  1           1            96                      0
#
#      STDepression  Slope  NumMajorVessels  Thalassemia  HeartDiseasePresence
# 136           0.0      2                0            2                     1

# %%
df.describe()#gives statistical info
# Out:
#               age      Gender  ChestPainType  RestingBloodPressure  \
# count  303.000000  303.000000     303.000000            303.000000
# mean    54.366337    0.683168       0.966997            131.623762
# std      9.082101    0.466011       1.032052             17.538143
# min     29.000000    0.000000       0.000000             94.000000
# 25%     47.500000    0.000000       0.000000            120.000000
# 50%     55.000000    1.000000       1.000000            130.000000
# 75%     61.000000    1.000000       2.000000            140.000000
# max     77.000000    1.000000       3.000000            200.000000
#
#        Cholesterol  FastingBloodSugar  RestingECG  MaxHeartRate  \
# count   303.000000         303.000000  303.000000    303.000000
# mean    246.264026           0.148515    0.528053    149.646865
# std      51.830751           0.356198    0.525860     22.905161
# min     126.000000           0.000000    0.000000     71.000000
# ...

# %%
df.shape #return dimension of dataframe
# Out:
# (303, 14)

# %%
df.columns #gives the name of columns present in the dataset
# Out:
# Index(['age', 'Gender', 'ChestPainType', 'RestingBloodPressure', 'Cholesterol',
#        'FastingBloodSugar', 'RestingECG', 'MaxHeartRate',
#        'ExerciseInducedAngina', 'STDepression', 'Slope', 'NumMajorVessels',
#        'Thalassemia', 'HeartDiseasePresence'],
#       dtype='object')

# %%
df.corr() #finds the correlation of each column in a DataFrame
# Out:
#                             age    Gender  ChestPainType  \
# age                    1.000000 -0.098447      -0.068653
# Gender                -0.098447  1.000000      -0.049353
# ChestPainType         -0.068653 -0.049353       1.000000
# RestingBloodPressure   0.279351 -0.056769       0.047608
# Cholesterol            0.213678 -0.197912      -0.076904
# FastingBloodSugar      0.121308  0.045032       0.094444
# RestingECG            -0.116211 -0.058196       0.044421
# MaxHeartRate          -0.398522 -0.044020       0.295762
# ExerciseInducedAngina  0.096801  0.141664      -0.394280
# STDepression           0.210013  0.096093      -0.149230
# Slope                 -0.168814 -0.030711       0.119717
# NumMajorVessels        0.276326  0.118261      -0.181053
# Thalassemia            0.068001  0.210041      -0.161736
# HeartDiseasePresence  -0.225439 -0.280937       0.433798
#
#                        RestingBloodPressure  Cholesterol  FastingBloodSugar  \
# ...

# %%
df.isnull().sum() #find the number of missing values in each column of a DataFrame
# Out:
# age                      0
# Gender                   0
# ChestPainType            0
# RestingBloodPressure     0
# Cholesterol              0
# FastingBloodSugar        0
# RestingECG               0
# MaxHeartRate             0
# ExerciseInducedAngina    0
# STDepression             0
# Slope                    0
# NumMajorVessels          0
# Thalassemia              0
# HeartDiseasePresence     0
# dtype: int64

# %%
df['Gender'].unique() #to check the types of gender
# Out:
# array([1, 0], dtype=int64)

# %%
#to check types of std depression
df["STDepression"].unique()
# Out:
# array([2.3, 3.5, 1.4, 0.8, 0.6, 0.4, 1.3, 0. , 0.5, 1.6, 1.2, 0.2, 1.8,
#        1. , 2.6, 1.5, 3. , 2.4, 0.1, 1.9, 4.2, 1.1, 2. , 0.7, 0.3, 0.9,
#        3.6, 3.1, 3.2, 2.5, 2.2, 2.8, 3.4, 6.2, 4. , 5.6, 2.9, 2.1, 3.8,
#        4.4])

# %%
#to check types of MaxHeartRate
df["MaxHeartRate"].unique()
# Out:
# array([150, 187, 172, 178, 163, 148, 153, 173, 162, 174, 160, 139, 171,
#        144, 158, 114, 151, 161, 179, 137, 157, 123, 152, 168, 140, 188,
#        125, 170, 165, 142, 180, 143, 182, 156, 115, 149, 146, 175, 186,
#        185, 159, 130, 190, 132, 147, 154, 202, 166, 164, 184, 122, 169,
#        138, 111, 145, 194, 131, 133, 155, 167, 192, 121,  96, 126, 105,
#        181, 116, 108, 129, 120, 112, 128, 109, 113,  99, 177, 141, 136,
#         97, 127, 103, 124,  88, 195, 106,  95, 117,  71, 118, 134,  90],
#       dtype=int64)

# %%
#to check how many  pateints are above or equal 35 age
df.loc[df["age"]>=35,["age",'ChestPainType']]
# Out:
#      age  ChestPainType
# 0     63              3
# 1     37              2
# 2     41              1
# 3     56              1
# 4     57              0
# ..   ...            ...
# 298   57              0
# 299   45              3
# 300   68              0
# 301   57              0
# 302   57              1
#
# [300 rows x 2 columns]

# %%
# to check how many males have chestpain
df.loc[df["Gender"]==1,["Gender",'ChestPainType']]
# Out:
#      Gender  ChestPainType
# 0         1              3
# 1         1              2
# 3         1              1
# 5         1              0
# 7         1              1
# ..      ...            ...
# 295       1              0
# 297       1              0
# 299       1              3
# 300       1              0
# 301       1              0
#
# [207 rows x 2 columns]

# %%
# to check how many females have chestpain
df.loc[df["Gender"]==1,["Gender",'ChestPainType']]
# Out:
#      Gender  ChestPainType
# 0         1              3
# 1         1              2
# 3         1              1
# 5         1              0
# 7         1              1
# ..      ...            ...
# 295       1              0
# 297       1              0
# 299       1              3
# 300       1              0
# 301       1              0
#
# [207 rows x 2 columns]

# %%
 # to check how many patient have 1 level of chestpain
df.loc[df["ChestPainType"]==3,["Gender","ChestPainType"]]
# Out:
#      Gender  ChestPainType
# 0         1              3
# 13        1              3
# 14        0              3
# 17        0              3
# 19        0              3
# 24        1              3
# 34        1              3
# 58        1              3
# 62        1              3
# 83        1              3
# 100       1              3
# 101       1              3
# 106       1              3
# 117       1              3
# 147       0              3
# 152       1              3
# 222       1              3
# 228       1              3
# 254       1              3
# 259       1              3
# 271       1              3
# 286       1              3
# 299       1              3

# %%
df.loc[(df["STDepression"]>=1.5)&(df["Gender"]==0),["age","ChestPainType"]]
# Out:
#      age  ChestPainType
# 15    50              2
# 17    66              3
# 19    69              3
# 40    51              2
# 85    67              2
# 88    54              2
# 105   68              2
# 120   64              0
# 151   71              0
# 167   62              0
# 204   62              0
# 207   60              0
# 215   43              0
# 220   63              0
# 223   56              0
# 246   56              0
# 252   62              0
# 263   63              0
# 266   55              0
# 289   55              0
# 292   58              0

# %%
 # to check senior citizen having chest pain type of level3
df.loc[(df["ChestPainType"]==3)&(df["age"]>=60),["age","ChestPainType"]]
# Out:
#      age  ChestPainType
# 0     63              3
# 13    64              3
# 17    66              3
# 19    69              3
# 106   69              3
# 147   60              3
# 152   64              3
# 222   65              3
# 271   61              3

# %%
# to check minimum and maximum RestingBloodPressure rate
print(df["RestingBloodPressure"].aggregate(["min","max"]))
# Out:
# min     94
# max    200
# Name: RestingBloodPressure, dtype: int64

# %%
# to check minimum and maximum MaxHeartRate
print(df["MaxHeartRate"].aggregate(["min","max"]))
# Out:
# min     71
# max    202
# Name: MaxHeartRate, dtype: int64

# %%
#data visualisation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15.,10))
sns.countplot(x="STDepression",data=df,width=0.5)
# Out:
# <Axes: xlabel='STDepression', ylabel='count'>

# %%
sns.histplot(df["Cholesterol"],bins=20,kde=True)
plt.title("cholesterol of patients ")
plt.xlabel("cholesterol")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
sns.scatterplot(data=df,x="age",y="RestingBloodPressure")
plt.title("age vs max RestingBloodPressure")
# Out:
# Text(0.5, 1.0, 'age vs max RestingBloodPressure')

# %%
sns.boxplot(data=df,x="ChestPainType",y="Cholesterol")
plt.title("Cholesterol level by Chestpain type")
# Out:
# Text(0.5, 1.0, 'Cholesterol level by Chestpain type')

# %%
#pie chart
df["RestingECG"].value_counts().plot.pie(autopct="%1.1f%%")
plt.title("RestingECG distribution")
# Out:
# Text(0.5, 1.0, 'RestingECG distribution')

# %%
#data visualisation
sns.countplot(x="Gender",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# box plot of Cholesterol
sns.boxplot(data=df,x= "Cholesterol" , y="Cholesterol")
plt.title("Cholesterol level by chestpain type")
# Out:
# Text(0.5, 1.0, 'Cholesterol level by chestpain type')
